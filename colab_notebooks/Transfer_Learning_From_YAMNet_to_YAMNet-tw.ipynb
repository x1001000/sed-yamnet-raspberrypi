# %% [markdown]
# <a href="https://colab.research.google.com/github/x1001000/raspberrypi3-yamnet-sed/blob/main/colab_notebooks/Transfer_Learning_From_YAMNet_to_YAMNet-tw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # runtime reset

# %% [markdown]
# ## install

# %%
# !pip install soundfile
# !pip install git+https://github.com/nficano/pytube
# !pip install pydub
# Out:
# Collecting soundfile
#   Downloading https://files.pythonhosted.org/packages/eb/f2/3cbbbf3b96fb9fa91582c438b574cff3f45b29c772f94c400e2c99ef5db9/SoundFile-0.10.3.post1-py2.py3-none-any.whl
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.6/dist-packages (from soundfile) (1.14.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi>=1.0->soundfile) (2.20)
# Installing collected packages: soundfile
# Successfully installed soundfile-0.10.3.post1
# Collecting git+https://github.com/nficano/pytube
#   Cloning https://github.com/nficano/pytube to /tmp/pip-req-build-5i1zoiy2
#   Running command git clone -q https://github.com/nficano/pytube /tmp/pip-req-build-5i1zoiy2
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.6/dist-packages (from pytube==10.4.1) (3.7.4.3)
# Building wheels for collected packages: pytube
#   Building wheel for pytube (setup.py) ... done
#   Created wheel for pytube: filename=pytube-10.4.1-cp36-none-any.whl size=43322 sha256=104b8590cc8ef8770f4ff04788c1086fcf75dbfcea451fdc4c7c6a75c4094808
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vtue6l7t/wheels/44/da/40/3b5e03abe33a91895343814fb44b309512375408f4a909555b
# Successfully built pytube
# Installing collected packages: pytube
# Successfully installed pytube-10.4.1
# Collecting pydub
#   Downloading https://files.pythonhosted.org/packages/7b/d1/fbfa79371a8cd9bb15c2e3c480d7e6e340ed5cc55005174e16f48418333a/pydub-0.24.1-py2.py3-none-any.whl
# Installing collected packages: pydub
# Successfully installed pydub-0.24.1

# %% [markdown]
# ## download YAMNet (15M bytes)

# %%
# !curl -O https://storage.googleapis.com/audioset/yamnet.h5
# !git clone https://github.com/tensorflow/models
# !cp models/research/audioset/yamnet/* .
# !git clone https://github.com/x1001000/raspberrypi3-yamnet-sed
# !cp raspberrypi3-yamnet-sed/yamnet/* .
# Out:
# Cloning into 'raspberrypi3-yamnet-sed'...
# remote: Enumerating objects: 232, done.
# remote: Counting objects: 100% (232/232), done.
# remote: Compressing objects: 100% (188/188), done.
# remote: Total 232 (delta 133), reused 89 (delta 41), pack-reused 0
# Receiving objects: 100% (232/232), 23.34 MiB | 20.04 MiB/s, done.
# Resolving deltas: 100% (133/133), done.

# %% [markdown]
# # runtime restart

# %% [markdown]
# ## import

# %%
import numpy as np
import resampy
import soundfile as sf
import tensorflow as tf

import params as yamnet_params
import yamnet as yamnet_model

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import models

from pytube import Playlist, YouTube
from pydub import AudioSegment

from IPython.display import display, Audio
from time import sleep

# %% [markdown]
# ## load YAMNet (3.7M params)

# %%
params = yamnet_params.Params()
yamnet = yamnet_model.yamnet_frames_model(params)
yamnet.load_weights('yamnet.h5')
yamnet_classes = yamnet_model.class_names('yamnet_class_map_zh-tw.csv')

yamnet.summary()
# Out:
# Model: "yamnet_frames"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None,)]            0
# __________________________________________________________________________________________________
# tf.compat.v1.shape (TFOpLambda) (1,)                 0           input_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem (Slici ()                   0           tf.compat.v1.shape[0][0]
# __________________________________________________________________________________________________
# tf.math.maximum_1 (TFOpLambda)  ()                   0           tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_1 (TFOpLambda) ()                   0           tf.math.maximum_1[0][0]
# __________________________________________________________________________________________________
# tf.cast (TFOpLambda)            ()                   0           tf.math.subtract_1[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv (TFOpLambda)    ()                   0           tf.cast[0][0]
# __________________________________________________________________________________________________
# tf.math.ceil (TFOpLambda)       ()                   0           tf.math.truediv[0][0]
# __________________________________________________________________________________________________
# tf.cast_1 (TFOpLambda)          ()                   0           tf.math.ceil[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract (TFOpLambda)   ()                   0           tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply (TFOpLambda)   ()                   0           tf.cast_1[0][0]
# __________________________________________________________________________________________________
# tf.math.maximum (TFOpLambda)    ()                   0           tf.math.subtract[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_2 (TFOpLambda) ()                   0           tf.math.multiply[0][0]
#                                                                  tf.math.subtract_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd ()                   0           tf.math.maximum[0][0]
#                                                                  tf.math.subtract_2[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.pad (TFOpLambda)   (None,)              0           input_1[0][0]
#                                                                  tf.__operators__.add[0][0]
# __________________________________________________________________________________________________
# tf.signal.stft (TFOpLambda)     (None, 257)          0           tf.compat.v1.pad[0][0]
# __________________________________________________________________________________________________
# tf.math.abs (TFOpLambda)        (None, 257)          0           tf.signal.stft[0][0]
# __________________________________________________________________________________________________
# tf.linalg.matmul (TFOpLambda)   (None, 64)           0           tf.math.abs[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLam (None, 64)           0           tf.linalg.matmul[0][0]
# __________________________________________________________________________________________________
# tf.math.log (TFOpLambda)        (None, 64)           0           tf.__operators__.add_1[0][0]
# __________________________________________________________________________________________________
# tf.signal.frame (TFOpLambda)    (None, 96, 64)       0           tf.math.log[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 96, 64, 1)    0           tf.signal.frame[0][0]
# __________________________________________________________________________________________________
# layer1/conv (Conv2D)            (None, 48, 32, 32)   288         reshape[0][0]
# __________________________________________________________________________________________________
# layer1/conv/bn (BatchNormalizat (None, 48, 32, 32)   96          layer1/conv[0][0]
# __________________________________________________________________________________________________
# layer1/relu (ReLU)              (None, 48, 32, 32)   0           layer1/conv/bn[0][0]
# __________________________________________________________________________________________________
# layer2/depthwise_conv (Depthwis (None, 48, 32, 32)   288         layer1/relu[0][0]
# __________________________________________________________________________________________________
# layer2/depthwise_conv/bn (Batch (None, 48, 32, 32)   96          layer2/depthwise_conv[0][0]
# __________________________________________________________________________________________________
# layer2/depthwise_conv/relu (ReL (None, 48, 32, 32)   0           layer2/depthwise_conv/bn[0][0]
# __________________________________________________________________________________________________
# layer2/pointwise_conv (Conv2D)  (None, 48, 32, 64)   2048        layer2/depthwise_conv/relu[0][0]
# __________________________________________________________________________________________________
# layer2/pointwise_conv/bn (Batch (None, 48, 32, 64)   192         layer2/pointwise_conv[0][0]
# __________________________________________________________________________________________________
# layer2/pointwise_conv/relu (ReL (None, 48, 32, 64)   0           layer2/pointwise_conv/bn[0][0]
# __________________________________________________________________________________________________
# layer3/depthwise_conv (Depthwis (None, 24, 16, 64)   576         layer2/pointwise_conv/relu[0][0]
# __________________________________________________________________________________________________
# layer3/depthwise_conv/bn (Batch (None, 24, 16, 64)   192         layer3/depthwise_conv[0][0]
# __________________________________________________________________________________________________
# layer3/depthwise_conv/relu (ReL (None, 24, 16, 64)   0           layer3/depthwise_conv/bn[0][0]
# __________________________________________________________________________________________________
# layer3/pointwise_conv (Conv2D)  (None, 24, 16, 128)  8192        layer3/depthwise_conv/relu[0][0]
# __________________________________________________________________________________________________
# layer3/pointwise_conv/bn (Batch (None, 24, 16, 128)  384         layer3/pointwise_conv[0][0]
# __________________________________________________________________________________________________
# layer3/pointwise_conv/relu (ReL (None, 24, 16, 128)  0           layer3/pointwise_conv/bn[0][0]
# __________________________________________________________________________________________________
# layer4/depthwise_conv (Depthwis (None, 24, 16, 128)  1152        layer3/pointwise_conv/relu[0][0]
# __________________________________________________________________________________________________
# layer4/depthwise_conv/bn (Batch (None, 24, 16, 128)  384         layer4/depthwise_conv[0][0]
# __________________________________________________________________________________________________
# layer4/depthwise_conv/relu (ReL (None, 24, 16, 128)  0           layer4/depthwise_conv/bn[0][0]
# __________________________________________________________________________________________________
# layer4/pointwise_conv (Conv2D)  (None, 24, 16, 128)  16384       layer4/depthwise_conv/relu[0][0]
# __________________________________________________________________________________________________
# layer4/pointwise_conv/bn (Batch (None, 24, 16, 128)  384         layer4/pointwise_conv[0][0]
# __________________________________________________________________________________________________
# layer4/pointwise_conv/relu (ReL (None, 24, 16, 128)  0           layer4/pointwise_conv/bn[0][0]
# __________________________________________________________________________________________________
# layer5/depthwise_conv (Depthwis (None, 12, 8, 128)   1152        layer4/pointwise_conv/relu[0][0]
# __________________________________________________________________________________________________
# layer5/depthwise_conv/bn (Batch (None, 12, 8, 128)   384         layer5/depthwise_conv[0][0]
# __________________________________________________________________________________________________
# layer5/depthwise_conv/relu (ReL (None, 12, 8, 128)   0           layer5/depthwise_conv/bn[0][0]
# __________________________________________________________________________________________________
# layer5/pointwise_conv (Conv2D)  (None, 12, 8, 256)   32768       layer5/depthwise_conv/relu[0][0]
# __________________________________________________________________________________________________
# layer5/pointwise_conv/bn (Batch (None, 12, 8, 256)   768         layer5/pointwise_conv[0][0]
# __________________________________________________________________________________________________
# layer5/pointwise_conv/relu (ReL (None, 12, 8, 256)   0           layer5/pointwise_conv/bn[0][0]
# __________________________________________________________________________________________________
# layer6/depthwise_conv (Depthwis (None, 12, 8, 256)   2304        layer5/pointwise_conv/relu[0][0]
# __________________________________________________________________________________________________
# layer6/depthwise_conv/bn (Batch (None, 12, 8, 256)   768         layer6/depthwise_conv[0][0]
# __________________________________________________________________________________________________
# layer6/depthwise_conv/relu (ReL (None, 12, 8, 256)   0           layer6/depthwise_conv/bn[0][0]
# __________________________________________________________________________________________________
# layer6/pointwise_conv (Conv2D)  (None, 12, 8, 256)   65536       layer6/depthwise_conv/relu[0][0]
# __________________________________________________________________________________________________
# layer6/pointwise_conv/bn (Batch (None, 12, 8, 256)   768         layer6/pointwise_conv[0][0]
# __________________________________________________________________________________________________
# layer6/pointwise_conv/relu (ReL (None, 12, 8, 256)   0           layer6/pointwise_conv/bn[0][0]
# __________________________________________________________________________________________________
# layer7/depthwise_conv (Depthwis (None, 6, 4, 256)    2304        layer6/pointwise_conv/relu[0][0]
# __________________________________________________________________________________________________
# layer7/depthwise_conv/bn (Batch (None, 6, 4, 256)    768         layer7/depthwise_conv[0][0]
# __________________________________________________________________________________________________
# layer7/depthwise_conv/relu (ReL (None, 6, 4, 256)    0           layer7/depthwise_conv/bn[0][0]
# __________________________________________________________________________________________________
# layer7/pointwise_conv (Conv2D)  (None, 6, 4, 512)    131072      layer7/depthwise_conv/relu[0][0]
# __________________________________________________________________________________________________
# layer7/pointwise_conv/bn (Batch (None, 6, 4, 512)    1536        layer7/pointwise_conv[0][0]
# __________________________________________________________________________________________________
# layer7/pointwise_conv/relu (ReL (None, 6, 4, 512)    0           layer7/pointwise_conv/bn[0][0]
# __________________________________________________________________________________________________
# layer8/depthwise_conv (Depthwis (None, 6, 4, 512)    4608        layer7/pointwise_conv/relu[0][0]
# __________________________________________________________________________________________________
# layer8/depthwise_conv/bn (Batch (None, 6, 4, 512)    1536        layer8/depthwise_conv[0][0]
# __________________________________________________________________________________________________
# layer8/depthwise_conv/relu (ReL (None, 6, 4, 512)    0           layer8/depthwise_conv/bn[0][0]
# __________________________________________________________________________________________________
# layer8/pointwise_conv (Conv2D)  (None, 6, 4, 512)    262144      layer8/depthwise_conv/relu[0][0]
# __________________________________________________________________________________________________
# layer8/pointwise_conv/bn (Batch (None, 6, 4, 512)    1536        layer8/pointwise_conv[0][0]
# __________________________________________________________________________________________________
# layer8/pointwise_conv/relu (ReL (None, 6, 4, 512)    0           layer8/pointwise_conv/bn[0][0]
# __________________________________________________________________________________________________
# layer9/depthwise_conv (Depthwis (None, 6, 4, 512)    4608        layer8/pointwise_conv/relu[0][0]
# __________________________________________________________________________________________________
# layer9/depthwise_conv/bn (Batch (None, 6, 4, 512)    1536        layer9/depthwise_conv[0][0]
# __________________________________________________________________________________________________
# layer9/depthwise_conv/relu (ReL (None, 6, 4, 512)    0           layer9/depthwise_conv/bn[0][0]
# __________________________________________________________________________________________________
# layer9/pointwise_conv (Conv2D)  (None, 6, 4, 512)    262144      layer9/depthwise_conv/relu[0][0]
# __________________________________________________________________________________________________
# layer9/pointwise_conv/bn (Batch (None, 6, 4, 512)    1536        layer9/pointwise_conv[0][0]
# __________________________________________________________________________________________________
# layer9/pointwise_conv/relu (ReL (None, 6, 4, 512)    0           layer9/pointwise_conv/bn[0][0]
# __________________________________________________________________________________________________
# layer10/depthwise_conv (Depthwi (None, 6, 4, 512)    4608        layer9/pointwise_conv/relu[0][0]
# __________________________________________________________________________________________________
# layer10/depthwise_conv/bn (Batc (None, 6, 4, 512)    1536        layer10/depthwise_conv[0][0]
# __________________________________________________________________________________________________
# layer10/depthwise_conv/relu (Re (None, 6, 4, 512)    0           layer10/depthwise_conv/bn[0][0]
# __________________________________________________________________________________________________
# layer10/pointwise_conv (Conv2D) (None, 6, 4, 512)    262144      layer10/depthwise_conv/relu[0][0]
# __________________________________________________________________________________________________
# layer10/pointwise_conv/bn (Batc (None, 6, 4, 512)    1536        layer10/pointwise_conv[0][0]
# __________________________________________________________________________________________________
# layer10/pointwise_conv/relu (Re (None, 6, 4, 512)    0           layer10/pointwise_conv/bn[0][0]
# __________________________________________________________________________________________________
# layer11/depthwise_conv (Depthwi (None, 6, 4, 512)    4608        layer10/pointwise_conv/relu[0][0]
# __________________________________________________________________________________________________
# layer11/depthwise_conv/bn (Batc (None, 6, 4, 512)    1536        layer11/depthwise_conv[0][0]
# __________________________________________________________________________________________________
# layer11/depthwise_conv/relu (Re (None, 6, 4, 512)    0           layer11/depthwise_conv/bn[0][0]
# __________________________________________________________________________________________________
# layer11/pointwise_conv (Conv2D) (None, 6, 4, 512)    262144      layer11/depthwise_conv/relu[0][0]
# __________________________________________________________________________________________________
# layer11/pointwise_conv/bn (Batc (None, 6, 4, 512)    1536        layer11/pointwise_conv[0][0]
# __________________________________________________________________________________________________
# layer11/pointwise_conv/relu (Re (None, 6, 4, 512)    0           layer11/pointwise_conv/bn[0][0]
# __________________________________________________________________________________________________
# layer12/depthwise_conv (Depthwi (None, 6, 4, 512)    4608        layer11/pointwise_conv/relu[0][0]
# __________________________________________________________________________________________________
# layer12/depthwise_conv/bn (Batc (None, 6, 4, 512)    1536        layer12/depthwise_conv[0][0]
# __________________________________________________________________________________________________
# layer12/depthwise_conv/relu (Re (None, 6, 4, 512)    0           layer12/depthwise_conv/bn[0][0]
# __________________________________________________________________________________________________
# layer12/pointwise_conv (Conv2D) (None, 6, 4, 512)    262144      layer12/depthwise_conv/relu[0][0]
# __________________________________________________________________________________________________
# layer12/pointwise_conv/bn (Batc (None, 6, 4, 512)    1536        layer12/pointwise_conv[0][0]
# __________________________________________________________________________________________________
# layer12/pointwise_conv/relu (Re (None, 6, 4, 512)    0           layer12/pointwise_conv/bn[0][0]
# __________________________________________________________________________________________________
# layer13/depthwise_conv (Depthwi (None, 3, 2, 512)    4608        layer12/pointwise_conv/relu[0][0]
# __________________________________________________________________________________________________
# layer13/depthwise_conv/bn (Batc (None, 3, 2, 512)    1536        layer13/depthwise_conv[0][0]
# __________________________________________________________________________________________________
# layer13/depthwise_conv/relu (Re (None, 3, 2, 512)    0           layer13/depthwise_conv/bn[0][0]
# __________________________________________________________________________________________________
# layer13/pointwise_conv (Conv2D) (None, 3, 2, 1024)   524288      layer13/depthwise_conv/relu[0][0]
# __________________________________________________________________________________________________
# layer13/pointwise_conv/bn (Batc (None, 3, 2, 1024)   3072        layer13/pointwise_conv[0][0]
# __________________________________________________________________________________________________
# layer13/pointwise_conv/relu (Re (None, 3, 2, 1024)   0           layer13/pointwise_conv/bn[0][0]
# __________________________________________________________________________________________________
# layer14/depthwise_conv (Depthwi (None, 3, 2, 1024)   9216        layer13/pointwise_conv/relu[0][0]
# __________________________________________________________________________________________________
# layer14/depthwise_conv/bn (Batc (None, 3, 2, 1024)   3072        layer14/depthwise_conv[0][0]
# __________________________________________________________________________________________________
# layer14/depthwise_conv/relu (Re (None, 3, 2, 1024)   0           layer14/depthwise_conv/bn[0][0]
# __________________________________________________________________________________________________
# layer14/pointwise_conv (Conv2D) (None, 3, 2, 1024)   1048576     layer14/depthwise_conv/relu[0][0]
# __________________________________________________________________________________________________
# layer14/pointwise_conv/bn (Batc (None, 3, 2, 1024)   3072        layer14/pointwise_conv[0][0]
# __________________________________________________________________________________________________
# layer14/pointwise_conv/relu (Re (None, 3, 2, 1024)   0           layer14/pointwise_conv/bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1024)         0           layer14/pointwise_conv/relu[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 521)          534025      global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 521)          0           dense[0][0]
# ==================================================================================================
# Total params: 3,751,369
# Trainable params: 3,729,481
# Non-trainable params: 21,888
# __________________________________________________________________________________________________

# %% [markdown]
# ## def data_from(YouTube)

# %%
def data_from(url, begin=1, end=None):
    waveforms = []
    titles = []
    for url in Playlist(url).video_urls[begin-1:end]:
        sleep(10) # HTTP 429 hack
        streams = YouTube(url).streams
        if streams.get_audio_only():
            default_filename = streams.get_audio_only().default_filename
            print(streams.get_audio_only().download())
            AudioSegment.from_file(default_filename).export(default_filename+'.wav', format='wav')
            wav_data, sr = sf.read(default_filename+'.wav', dtype=np.int16)
            assert wav_data.dtype == np.int16, 'Bad sample type: %r' % wav_data.dtype
            waveform = wav_data / tf.int16.max#32768.0  # Convert to [-1.0, +1.0]
            waveform = waveform.astype('float32')

            # Convert to mono and the sample rate expected by YAMNet.
            if len(waveform.shape) > 1:
                waveform = np.mean(waveform, axis=1)
            if sr != params.sample_rate:
                waveform = resampy.resample(waveform, sr, params.sample_rate)

            waveforms.append(waveform)
            titles.append(YouTube(url).title)
        else:
            print('No audio_only stream!')
    return waveforms, titles

# %% [markdown]
# # data prep for TRAINING and TESTING

# %% [markdown]
# ## extract features X and encode labels Y from classified playlists

# %%
CLASSES = 2

# %%
# TRAINING_data
playlists = [(0, ['https://www.youtube.com/playlist?list=PL0Q2eQA7p-wQIB3c6siLyc8qa25iIDiKq']), # Other
             (1, ['https://www.youtube.com/playlist?list=PL9deQcOOEJtV7_M52CH819jcN9Ty7ql0h'])] # 垃圾車

X = Y = 0
for label, playlist in playlists:
    waveforms, titles = data_from(*playlist)
    for waveform, title in zip(waveforms, titles):
        if type(X) == type(Y) == int:
            scores, embeddings, spectrogram = yamnet(waveform)
            X = embeddings
            Y = tf.one_hot(np.array([label] * len(embeddings)), depth=CLASSES)
        else:
            scores, embeddings, spectrogram = yamnet(waveform)
            X = np.concatenate((X, embeddings))
            Y = np.concatenate((Y, tf.one_hot(np.array([label] * len(embeddings)), depth=CLASSES)))
        print(X.shape, Y.shape, title)
TRAINING_data = X, Y
# Out:
# /content/目前最長的一期，只有五歲抬頭才能看懂的天能（信条）  老高與小茉 Mr & Mrs Gao.mp4
# /content/圣诞歌曲 🎄  聖誕歌 英语 2020 🎅 聖誕歌曲合輯 英语 🎅 聖誕節歌曲 🎄 聖誕節 安靜音樂 🎅 祝大家聖誕快樂 🎄 🎅christmas songs.mp4
# /content/City Street Ambience Sound Effect [FREE DOWNLOAD  ROYALTY FREE].mp4
# /content/繁忙的街道和道路环境声 - 30分钟.mp4
# /content/救護車的聲音.mp4
# /content/警車警笛聲 EP1 提供大家下載！！！.mp4
# /content/消防車聲精選.mp4
# /content/小孩哭哭出來.mp4
# /content/Natalie的嬰兒哭聲.mp4
# /content/超級療癒的笑聲.mp4
# (4516, 1024) (4516, 2) 目前最長的一期，只有五歲抬頭才能看懂的天能（信条） | 老高與小茉 Mr & Mrs Gao
# (10043, 1024) (10043, 2) 圣诞歌曲 🎄  聖誕歌 英语 2020 🎅 聖誕歌曲合輯 英语 🎅 聖誕節歌曲 🎄 聖誕節 安靜音樂 🎅 祝大家聖誕快樂 🎄 🎅christmas songs
# (10457, 1024) (10457, 2) City Street Ambience Sound Effect [FREE DOWNLOAD | ROYALTY FREE]
# (14207, 1024) (14207, 2) 繁忙的街道和道路环境声 - 30分钟
# (14269, 1024) (14269, 2) 救護車的聲音
# (14351, 1024) (14351, 2) 警車警笛聲 EP.1 提供大家下載！！！
# (14563, 1024) (14563, 2) 消防車聲精選
# (14605, 1024) (14605, 2) 小孩哭哭出來
# (14633, 1024) (14633, 2) Natalie的嬰兒哭聲
# (14664, 1024) (14664, 2) 超級療癒的笑聲
# /content/20200926彰化縣和美鎮垃圾車441-VQ，回收車4813-PU(切換音樂).mp4
# /content/20200926和美鎮(新)垃圾車KEJ-7509(取代723-UD)，回收車KEE-9395(取代BR-790).mp4
# /content/20200825彰化縣和美鎮垃圾車987-Q3，回收車319-UD.mp4
# /content/20200825和美鎮垃圾車641-VQ(代441-VQ)，回收車4813-PU(線西，和美交界).mp4
# /content/20200825彰化縣和美鎮垃圾車440-VQ，回收車AFQ-6395(彰化，和美交界).mp4
# (16076, 1024) (16076, 2) 20200926彰化縣和美鎮垃圾車441-VQ，回收車4813-PU(切換音樂)
# (17328, 1024) (17328, 2) 20200926和美鎮(新)垃圾車KEJ-7509(取代723-UD)，回收車KEE-9395(取代BR-790)
# (18082, 1024) (18082, 2) 20200825彰化縣和美鎮垃圾車987-Q3，回收車319-UD
# (18863, 1024) (18863, 2) 20200825和美鎮垃圾車641-VQ(代441-VQ)，回收車4813-PU(線西，和美交界)
# (19937, 1024) (19937, 2) 20200825彰化縣和美鎮垃圾車440-VQ，回收車AFQ-6395(彰化，和美交界)

# %%
# TESTING_data
playlists = [(0, ['https://www.youtube.com/playlist?list=PL0Q2eQA7p-wQwTP-Wk7nSHdpAFnU2kCSW']), # Other
             (1, ['https://www.youtube.com/playlist?list=PL9deQcOOEJtUKab8VBKnom0d8BrYBsvlg'])] # 垃圾車

X = Y = 0
for label, playlist in playlists:
    waveforms, titles = data_from(*playlist)
    for waveform, title in zip(waveforms, titles):
        if type(X) == type(Y) == int:
            scores, embeddings, spectrogram = yamnet(waveform)
            X = embeddings
            Y = tf.one_hot(np.array([label] * len(embeddings)), depth=CLASSES)
        else:
            scores, embeddings, spectrogram = yamnet(waveform)
            X = np.concatenate((X, embeddings))
            Y = np.concatenate((Y, tf.one_hot(np.array([label] * len(embeddings)), depth=CLASSES)))
        print(X.shape, Y.shape, title)
TESTING_data = X, Y
# Out:
# /content/Wydif after work party in Silicon Valley.mp4
# /content/Apple - iPhone 5s - Dreams.mp4
# /content/Welcome to Project Soli.mp4
# /content/Annas Story.mp4
# /content/Working at Google in Taiwan Software Engineering.mp4
# /content/Life as Software Engineer @ Google Taiwan (Mandarin) 線上直播.mp4
# /content/Official Intro  GTC 2019  I AM AI.mp4
# /content/Making your Raspberry Pi 3B+ in Wales UK.mp4
# /content/超恥辱! 公開我們的第一支影片! feat 頻道健檢活動.mp4
# /content/CS50 Lecture by Mark Zuckerberg - 7 December 2005.mp4
# (242, 1024) (242, 2) Wydif: after work party in Silicon Valley
# (369, 1024) (369, 2) Apple - iPhone 5s - Dreams
# (860, 1024) (860, 2) Welcome to Project Soli
# (1096, 1024) (1096, 2) Anna's Story
# (8568, 1024) (8568, 2) Working at Google in Taiwan: Software Engineering
# (13301, 1024) (13301, 2) Life as Software Engineer @ Google Taiwan (Mandarin) 線上直播
# (13646, 1024) (13646, 2) Official Intro | GTC 2019 | I AM AI
# (13738, 1024) (13738, 2) Making your Raspberry Pi 3B+ in Wales, UK
# (15833, 1024) (15833, 2) 超恥辱! 公開我們的第一支影片! feat. 頻道健檢活動
# (24029, 1024) (24029, 2) CS50 Lecture by Mark Zuckerberg - 7 December 2005
# /content/2020090910福興鄉垃圾車KED-5321(代763-UX)，回收車KEG-9913.mp4
# /content/20200805鹿港鎮，福興鄉垃圾車956-UR，848-UD，回收車KED-5002.mp4
# /content/20200721彰化縣福興鄉垃圾車848-UD，回收車KED-5002.mp4
# /content/20200722彰化縣福興鄉垃圾車723-UX，回收車755-UD.mp4
# /content/20200722彰化縣福興鄉垃圾車700-VQ，回收車KEB-2693.mp4
# /content/20200720 0805福興鄉垃圾車442-VQ(代721-UX)，回收車922-UD.mp4
# /content/20200717彰化縣福興鄉垃圾車722-UX，回收車365-UQ.mp4
# /content/20200714 21彰化縣福興鄉垃圾車763-UX，回收車KEG-9913.mp4
# (25288, 1024) (25288, 2) 20200909,10福興鄉垃圾車KED-5321(代763-UX)，回收車KEG-9913
# (25751, 1024) (25751, 2) 20200805鹿港鎮，福興鄉垃圾車956-UR，848-UD，回收車KED-5002
# (26401, 1024) (26401, 2) 20200721彰化縣福興鄉垃圾車848-UD，回收車KED-5002
# (27005, 1024) (27005, 2) 20200722彰化縣福興鄉垃圾車723-UX，回收車755-UD
# (27450, 1024) (27450, 2) 20200722彰化縣福興鄉垃圾車700-VQ，回收車KEB-2693
# (28275, 1024) (28275, 2) 20200720, 0805福興鄉垃圾車442-VQ(代721-UX)，回收車922-UD
# (28706, 1024) (28706, 2) 20200717彰化縣福興鄉垃圾車722-UX，回收車365-UQ
# (29372, 1024) (29372, 2) 20200714, 21彰化縣福興鄉垃圾車763-UX，回收車KEG-9913

# %% [markdown]
# ## know the shapes inside out

# %%
STFTs = 1 # No matter how short wav is, even 0s, 1 STFT will be done!
SR = int(params.sample_rate)
scores, embeddings, spectrogram = yamnet(waveform[:round((0.015 + 0.48*STFTs + 0.001)*SR)]) # round rather than int to avoid 0.30000000000000004.com
print(scores.shape)
print(embeddings.shape)
print(spectrogram.shape)
assert scores.shape[1] == 521 # audio event classes
assert embeddings.shape[1] == 1024 # -dimension embedding
assert spectrogram.shape[1] == 64 # mel bins covering the range 125-7500 Hz
assert len(scores) == len(embeddings) == len(spectrogram) / 48 - 1 == STFTs
# Out:
# (1, 521)
# (1, 1024)
# (96, 64)

# %% [markdown]
# # model TRAINING: model.fit

# %%
# https://www.tensorflow.org/guide/keras/sequential_model
model = keras.Sequential(
    [
        keras.Input(shape=1024),
        layers.Dense(512, activation="relu"),
        layers.Dense(2, activation="softmax"),
    ]
)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 525,826
# Trainable params: 525,826
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
X, Y = TRAINING_data
model.fit(x=X,
          y=Y,
          validation_split=0.2,
          batch_size=32,        # the smaller, the slower, limited by GPU if any
          epochs=100)
# Out:
# Epoch 1/100
# 499/499 [==============================] - 4s 6ms/step - loss: 0.0736 - accuracy: 0.9697 - val_loss: 0.2361 - val_accuracy: 0.9310
# Epoch 2/100
# 499/499 [==============================] - 2s 5ms/step - loss: 0.0113 - accuracy: 0.9966 - val_loss: 0.8371 - val_accuracy: 0.7640
# Epoch 3/100
# 499/499 [==============================] - 2s 5ms/step - loss: 0.0066 - accuracy: 0.9983 - val_loss: 0.6666 - val_accuracy: 0.8636
# Epoch 4/100
# 499/499 [==============================] - 2s 5ms/step - loss: 0.0055 - accuracy: 0.9984 - val_loss: 0.5598 - val_accuracy: 0.8974
# Epoch 5/100
# 499/499 [==============================] - 2s 5ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.6204 - val_accuracy: 0.9020
# Epoch 6/100
# 499/499 [==============================] - 2s 5ms/step - loss: 5.6445e-04 - accuracy: 0.9999 - val_loss: 0.7527 - val_accuracy: 0.8889
# Epoch 7/100
# 499/499 [==============================] - 2s 5ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 1.1641 - val_accuracy: 0.8232
# Epoch 8/100
# 499/499 [==============================] - 3s 5ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 1.2688 - val_accuracy: 0.8332
# Epoch 9/100
# 499/499 [==============================] - 2s 5ms/step - loss: 3.3845e-04 - accuracy: 1.0000 - val_loss: 0.8956 - val_accuracy: 0.8857
# Epoch 10/100
# 499/499 [==============================] - 2s 5ms/step - loss: 5.3877e-05 - accuracy: 1.0000 - val_loss: 0.9570 - val_accuracy: 0.8839
# Epoch 11/100
# 499/499 [==============================] - 2s 5ms/step - loss: 3.0348e-05 - accuracy: 1.0000 - val_loss: 0.9806 - val_accuracy: 0.8854
# Epoch 12/100
# 499/499 [==============================] - 2s 5ms/step - loss: 2.4831e-05 - accuracy: 1.0000 - val_loss: 0.9865 - val_accuracy: 0.8872
# Epoch 13/100
# 499/499 [==============================] - 2s 5ms/step - loss: 2.0260e-05 - accuracy: 1.0000 - val_loss: 1.0297 - val_accuracy: 0.8837
# Epoch 14/100
# 499/499 [==============================] - 2s 5ms/step - loss: 1.4625e-05 - accuracy: 1.0000 - val_loss: 1.0256 - val_accuracy: 0.8879
# Epoch 15/100
# 499/499 [==============================] - 3s 5ms/step - loss: 1.1204e-05 - accuracy: 1.0000 - val_loss: 1.0860 - val_accuracy: 0.8831
# Epoch 16/100
# 499/499 [==============================] - 3s 5ms/step - loss: 8.1725e-06 - accuracy: 1.0000 - val_loss: 1.0736 - val_accuracy: 0.8867
# Epoch 17/100
# 499/499 [==============================] - 2s 5ms/step - loss: 8.5606e-06 - accuracy: 1.0000 - val_loss: 1.0972 - val_accuracy: 0.8862
# Epoch 18/100
# 499/499 [==============================] - 2s 5ms/step - loss: 5.2205e-06 - accuracy: 1.0000 - val_loss: 1.1395 - val_accuracy: 0.8829
# Epoch 19/100
# 499/499 [==============================] - 2s 5ms/step - loss: 4.5186e-06 - accuracy: 1.0000 - val_loss: 1.1866 - val_accuracy: 0.8804
loss, accuracy = model.evaluate(X, Y)
accuracy
# Out:
# 918/918 [==============================] - 2s 2ms/step - loss: 0.4539 - accuracy: 0.9734
# 0.9734100699424744

# %%
model.save('model-126-1.h5')

# %% [markdown]
# # run inference w/wo a trained model on a playlist

# %% [markdown]
# ## load a trained classifier

# %%
#model = models.load_model('raspberrypi3-yamnet-sed/model-126-1.h5')

# %% [markdown]
# ## test a playlist for 5MA inference

# %%
playlist = ['https://www.youtube.com/playlist?list=PLk218Jsilveyr4dCO-LB-asqhIIl74Zt2']

MA = 5
SR = int(params.sample_rate)

waveforms, titles = data_from(*playlist)
for waveform, title in zip(waveforms, titles):
    #display(Audio(waveform, rate=SR)) # crashes if waveform is big
    print(title)
    #continue
    for i in range(MA, len(waveform)//SR, MA):
        scores, embeddings, spectrogram = yamnet(waveform[(i-MA)*SR:i*SR])
        classifier = np.argmax(np.mean(model.predict(embeddings[:-1]), axis=0), axis=-1)# = 0 as without a classifier
        if classifier == 0: # with only YAMNet
            # Scores is a matrix of (time_frames, num_classes) classifier scores.
            # Average them along time to get an overall classifier output for the clip.
            prediction = np.mean(scores[:-1], axis=0) # last score comes from insufficient samples
            # Report the highest-scoring classes #and their scores.
            top3 = np.argsort(prediction)[::-1][:3]
            print(f'{i//60}:{i%60:2d}',
                ''.join(f" {int(prediction[i]*10)}👈{yamnet_classes[i][:14].ljust(14, '　')}" for i in top3))
        elif classifier == 1:
            print(f'{i//60}:{i%60:2d}', "台灣音樂垃圾車")
# Out:
# /content/東河鄉公所 清潔隊 垃圾車 村莊 垃圾收運 (高畫質不專業錄影) 詳細請看說明.mp4
# /content/東河鄉公所 清潔隊 垃圾車  村莊 垃圾收運 (高畫質不專業錄影) 詳細請看說明.mp4
# /content/DONGFENG 裕隆東風 垃圾車 車內 視角 (高畫質不專業錄影) 2019年5月25拍攝.mp4
# /content/DAF 達富 垃圾車 (高畫質不專業錄影) 詳細請看說明.mp4
# 東河鄉公所 清潔隊 垃圾車 村莊 垃圾收運 (高畫質不專業錄影) 詳細請看說明
# 0: 5 台灣音樂垃圾車
# 0:10 台灣音樂垃圾車
# 0:15 台灣音樂垃圾車
# 0:20 台灣音樂垃圾車
# 0:25 台灣音樂垃圾車
# 0:30 台灣音樂垃圾車
# 0:35 台灣音樂垃圾車
# 0:40 台灣音樂垃圾車
# 0:45 台灣音樂垃圾車
# 0:50 台灣音樂垃圾車
# 0:55 台灣音樂垃圾車
# 1: 0 台灣音樂垃圾車
# 1: 5 台灣音樂垃圾車
# 1:10 台灣音樂垃圾車
# 1:15 台灣音樂垃圾車
# 1:20 台灣音樂垃圾車
# 1:25 台灣音樂垃圾車
# 1:30 台灣音樂垃圾車
# 1:35 台灣音樂垃圾車
# 1:40 台灣音樂垃圾車
# 1:45 台灣音樂垃圾車
# 1:50 台灣音樂垃圾車
# 1:55 台灣音樂垃圾車
# 2: 0 台灣音樂垃圾車
# 2: 5 台灣音樂垃圾車
# 2:10 台灣音樂垃圾車
# 2:15 台灣音樂垃圾車
# 2:20 台灣音樂垃圾車
