# %% [markdown]
# <a href="https://colab.research.google.com/github/x1001000/raspberrypi3-yamnet-sed/blob/main/colab_notebooks/Flourish_bar_chart_race_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/x1001000/raspberrypi3-yamnet-sed
# !cp raspberrypi3-yamnet-sed/yamnet/* .
# Out:
# Cloning into 'raspberrypi3-yamnet-sed'...
# remote: Enumerating objects: 78, done.
# remote: Counting objects: 100% (78/78), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 340 (delta 39), reused 24 (delta 11), pack-reused 262
# Receiving objects: 100% (340/340), 52.03 MiB | 30.29 MiB/s, done.
# Resolving deltas: 100% (191/191), done.

# %%
import time
import numpy as np
import pandas as pd
df = pd.DataFrame(columns=[''] + list(pd.read_csv('yamnet_class_map_zh-tw.csv')['display_name']))
with open('20210318-1112.npy', 'rb') as f:
    df.loc[len(df)] = np.load(f)
    while True:
        try:
            df.loc[len(df)] = np.load(f)
        except:
            break
df[''] = pd.to_datetime(df[''], unit='s') + pd.Timedelta('8:0:0')
df
# Out:
#                                          言語  ...       無線電      現場記錄
# 0   2021-03-18 11:57:48.734139681  0.006818  ...  0.000052  0.000031
# 1   2021-03-18 11:57:50.360708714  0.000749  ...  0.000015  0.001627
# 2   2021-03-18 11:57:51.951300621  0.000231  ...  0.000008  0.003075
# 3   2021-03-18 11:57:53.531133175  0.002022  ...  0.000008  0.000037
# 4   2021-03-18 11:57:55.104258060  0.000347  ...  0.000003  0.000035
# ..                            ...       ...  ...       ...       ...
# 900 2021-03-18 12:21:36.428554773  0.003123  ...  0.000011  0.001307
# 901 2021-03-18 12:21:38.006190300  0.015532  ...  0.000033  0.000830
# 902 2021-03-18 12:21:39.611936092  0.011866  ...  0.000200  0.000626
# 903 2021-03-18 12:21:41.190615654  0.004133  ...  0.000074  0.000718
# 904 2021-03-18 12:21:42.768555403  0.003580  ...  0.000123  0.003702
#
# [905 rows x 522 columns]

# %%
df.T.to_csv('data.csv', header=False, index=True)
